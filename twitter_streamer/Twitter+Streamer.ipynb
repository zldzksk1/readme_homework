# %% [markdown]
# Use `pip` to install `twitter`.

# %%
# !pip install twitter
#!pip install twitter --quiet 이렇게 하면 아웃풋을 안보여줌
# Out:
# Requirement already satisfied: twitter in /opt/conda/lib/python3.6/site-packages
# You are using pip version 9.0.3, however version 10.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# Import `TwitterStream` and `OAuth` from `twitter`.

# %%
from twitter import OAuth, TwitterStream

# %% [markdown]
# ### `oauth`

# %% [markdown]
# Create a new object called `oauth` using `OAuth`.
#
#     OAuth(token, token_secret, consumer_key, consumer_secret)

# %%
token           = "1019793622953222145-AKiXmsPpBVajjRThKEafxqi8Kv9Zvd"
token_secret    = "PWXH26H61SM44ggxJhYVwlndYP9Qnw6xsv9c3nWdz2ZnS"
consumer_key    = "jNQiuHX128wrIEwGNRefUNdCu"
consumer_secret = "jZtWy8x4hU5rfhTPXXFuTEMuKrc6cgzi2mLEYkthPgTYHDiTrr"

# %%
oauth = OAuth(token, token_secret, consumer_key, consumer_secret)

# %% [markdown]
# Create a new object called `twitter_stream` using `TwitterStream`.
#
# Use the argument `auth=oauth` referencing the `oauth` object you just made.

# %% [markdown]
# ### `twitter_stream`

# %%
twitter_stream = TwitterStream(auth=oauth)

# %% [markdown]
# ### `bounding_box`

# %% [markdown]
# Create a string called `bounding_box`. The string should contain the geo-coordinates of a bounding box separated by commas. These values are for Santa Monica:
#
#     -118.5137323688,34.0001996344,-118.4702449172,34.0331651696
#
# You can make your own here: https://boundingbox.klokantech.com. Be sure to specify CSV RAW to get the values in this format.
#
# ![](https://www.evernote.com/l/AAH3H9KGE6hD9JpPJPFncw09exRyoYSid5IB/image.png)

# %%
bounding_box = '-118.5137323688,34.0001996344,-118.4702449172,34.0331651696'

# %% [markdown]
# ### `tweet_iterator`
#
# Create an object called `tweet_iterator`.
#
# 1. Use `twitter_stream`.
# 1. Apply `.statuses` to grab statuses.
# 1. Apply a `.filter()` with the argument `locations=bounding_box`.

# %%
tweet_iterator = twitter_stream.statuses.filter(locations=bounding_box)

# %% [markdown]
# Get the next value from the `tweet_iterator` and store it as the variable `this_tweet`.

# %%
this_tweet = next(tweet_iterator)

# %% [markdown]
# What is the type of `this_tweet`?

# %%
type(this_tweet)
# Out:
# twitter.api.TwitterDictResponse

# %% [markdown]
# Display the keys of `this_tweet`.

# %%
this_tweet.keys()
#for key in this_tweet.items() :
#    print (key)
# Out:
# dict_keys(['created_at', 'id', 'id_str', 'text', 'source', 'truncated', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'in_reply_to_screen_name', 'user', 'geo', 'coordinates', 'place', 'contributors', 'quoted_status_id', 'quoted_status_id_str', 'quoted_status', 'quoted_status_permalink', 'is_quote_status', 'quote_count', 'reply_count', 'retweet_count', 'favorite_count', 'entities', 'favorited', 'retweeted', 'filter_level', 'lang', 'timestamp_ms'])

# %% [markdown]
# Display the `text` and `user` of `this_tweet`.

# %%
this_tweet['text']
# Out:
# 'amazing'

# %%
this_tweet['user']
# Out:
# {'id': 163937334,
#  'id_str': '163937334',
#  'name': 'Mary Jane Gibson',
#  'screen_name': 'thisismaryjane_',
#  'location': 'Los Angeles, CA',
#  'url': None,
#  'description': '🌱',
#  'translator_type': 'none',
#  'protected': False,
#  'verified': False,
#  'followers_count': 1939,
#  'friends_count': 1057,
#  'listed_count': 26,
#  'favourites_count': 10177,
#  'statuses_count': 2011,
#  'created_at': 'Wed Jul 07 16:56:59 +0000 2010',
#  'utc_offset': None,
#  'time_zone': None,
#  'geo_enabled': True,
#  'lang': 'en',
#  'contributors_enabled': False,
#  'is_translator': False,
#  'profile_background_color': 'EDECE9',
#  'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme3/bg.gif',
#  'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme3/bg.gif',
#  'profile_background_tile': False,
#  'profile_link_color': '088253',
#  'profile_sidebar_border_color': 'D3D2CF',
#  'profile_sidebar_fill_color': 'E3E2DE',
#  'profile_text_color': '634047',
#  'profile_use_background_image': True,
#  'profile_image_url': 'http://pbs.twimg.com/profile_images/1006981850160496640/F1xEaKns_normal.jpg',
#  'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1006981850160496640/F1xEaKns_normal.jpg',
#  'profile_banner_url': 'https://pbs.twimg.com/profile_banners/163937334/1528918238',
#  'default_profile': False,
#  'default_profile_image': False,
#  'following': None,
#  'follow_request_sent': None,
#  'notifications': None}

# %% [markdown]
# ## Collect Tweets
#
# Create an empty list called `tweets`.
#
# Use a `for`-loop to collect ten tweets and add them to this list.

# %%
tweets = []
for i in range(10):
    this_tweet = next(tweet_iterator)
    tweets.append(this_tweet)

# %%
tweets
# Out:
# [{'created_at': 'Fri Jul 20 03:13:56 +0000 2018',
#   'id': 1020144750395981825,
#   'id_str': '1020144750395981825',
#   'text': 'i need to be tweeting julie’s outfits like #getnicoletobigbrotherlive',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 112626095,
#    'id_str': '112626095',
#    'name': 'nicole',
#    'screen_name': 'nicolecclark',
#    'location': None,
#    'url': None,
#    'description': 'yes, that is pablo escobar in my header',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 409,
#    'friends_count': 341,
#    'listed_count': 1,
#    'favourites_count': 5244,
#    'statuses_count': 5255,
#    'created_at': 'Tue Feb 09 04:57:10 +0000 2010',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '89C9FA',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme18/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '3B94D9',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'F6F6F6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1004263391186190336/AFiuYVM5_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1004263391186190336/AFiuYVM5_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/112626095/1474665468',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [{'text': 'getnicoletobigbrotherlive',
#      'indices': [43, 69]}],
#    'urls': [],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056436524'},
#  {'created_at': 'Fri Jul 20 03:13:57 +0000 2018',
#   'id': 1020144755588542464,
#   'id_str': '1020144755588542464',
#   'text': 'Precisely',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 19262339,
#    'id_str': '19262339',
#    'name': 'Andrew Shikiar',
#    'screen_name': 'andrewshikiar',
#    'location': 'ÜT: 37.603159,-122.377032',
#    'url': 'http://www.linkedin.com/in/andrewshikiar',
#    'description': '206-raised, LA-based exec in emerging tech. Dad to 2 girls. CMO at @FIDOAlliance. Tweets = my opinions on tech, politics & (mainly) Seattle sports.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 392,
#    'friends_count': 234,
#    'listed_count': 101,
#    'favourites_count': 1535,
#    'statuses_count': 5105,
#    'created_at': 'Tue Jan 20 22:42:19 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '9AE4E8',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'BDDCAD',
#    'profile_sidebar_fill_color': 'DDFFCC',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1002853570440507392/5u-TibMW_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1002853570440507392/5u-TibMW_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/19262339/1524260622',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'quoted_status_id': 1020119903142072320,
#   'quoted_status_id_str': '1020119903142072320',
#   'quoted_status': {'created_at': 'Fri Jul 20 01:35:12 +0000 2018',
#    'id': 1020119903142072320,
#    'id_str': '1020119903142072320',
#    'text': 'A superb piece by @megangarber: "...it becomes clear, if you watch for long enough, that the thing being fought for… https://t.co/LqHtJBkc0i',
#    'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#    'truncated': True,
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 1051396218,
#     'id_str': '1051396218',
#     'name': 'Evan McMullin',
#     'screen_name': 'Evan_McMullin',
#     'location': None,
#     'url': 'http://StandUpRepublic.com',
#     'description': 'Co-founder of @StandUpRepublic and @StandUpIdeas with @mindyfinn. Former independent presidential candidate, CIA operations officer & House GOP policy director.',
#     'translator_type': 'none',
#     'protected': False,
#     'verified': True,
#     'followers_count': 460061,
#     'friends_count': 6573,
#     'listed_count': 4852,
#     'favourites_count': 10387,
#     'statuses_count': 7053,
#     'created_at': 'Mon Dec 31 23:31:03 +0000 2012',
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'profile_background_color': 'DD2E44',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/771412672738955264/sRBfBvjW_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/771412672738955264/sRBfBvjW_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1051396218/1512444539',
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': None,
#     'follow_request_sent': None,
#     'notifications': None},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'extended_tweet': {'full_text': 'A superb piece by @megangarber: "...it becomes clear, if you watch for long enough, that the thing being fought for is reality itself: facts, truths, common knowledge. The content and the contours of the world as we agree to understand it." https://t.co/vlk56QOeT2',
#     'display_text_range': [0, 264],
#     'entities': {'hashtags': [],
#      'urls': [{'url': 'https://t.co/vlk56QOeT2',
#        'expanded_url': 'https://www.theatlantic.com/entertainment/archive/2018/07/sarah-sanders-russia-and-the-absolution-of-chaos/565610/',
#        'display_url': 'theatlantic.com/entertainment/…',
#        'indices': [241, 264]}],
#      'user_mentions': [{'screen_name': 'megangarber',
#        'name': 'Megan Garber',
#        'id': 18751963,
#        'id_str': '18751963',
#        'indices': [18, 30]}],
#      'symbols': []}},
#    'quote_count': 29,
#    'reply_count': 79,
#    'retweet_count': 866,
#    'favorite_count': 1980,
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/LqHtJBkc0i',
#       'expanded_url': 'https://twitter.com/i/web/status/1020119903142072320',
#       'display_url': 'twitter.com/i/web/status/1…',
#       'indices': [117, 140]}],
#     'user_mentions': [{'screen_name': 'megangarber',
#       'name': 'Megan Garber',
#       'id': 18751963,
#       'id_str': '18751963',
#       'indices': [18, 30]}],
#     'symbols': []},
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'filter_level': 'low',
#    'lang': 'en'},
#   'quoted_status_permalink': {'url': 'https://t.co/GWLvP4sqgI',
#    'expanded': 'https://twitter.com/evan_mcmullin/status/1020119903142072320',
#    'display': 'twitter.com/evan_mcmullin/…'},
#   'is_quote_status': True,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [], 'urls': [], 'user_mentions': [], 'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056437762'},
#  {'created_at': 'Fri Jul 20 03:13:58 +0000 2018',
#   'id': 1020144758973485056,
#   'id_str': '1020144758973485056',
#   'text': 'When its 199degrees 🔅in the Valley, you do the best tasty treats on Ventura Blvd. at Wanderlust Creamery… https://t.co/72R8WlOZWm',
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 262341207,
#    'id_str': '262341207',
#    'name': 'Brian dj fly Samson',
#    'screen_name': 'BSamson209',
#    'location': 'Los Angeles',
#    'url': None,
#    'description': "Serving West Coast DJ's since 1984..\nManager: @Abrinamusic @DerekKingonline @rawsmoovbeats   \nBLUEPRINT PROMO: @JAYnFresh @whoiscadence \nIG/bsamsonwestcoast",
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1728,
#    'friends_count': 2004,
#    'listed_count': 29,
#    'favourites_count': 8,
#    'statuses_count': 1670,
#    'created_at': 'Mon Mar 07 21:31:40 +0000 2011',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '910A0A',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '2DD7ED',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'B31E32',
#    'profile_text_color': '0F0F0F',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/998805467492110336/QaCd-7bk_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/998805467492110336/QaCd-7bk_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/262341207/1526969035',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [34.16924, -118.53652]},
#   'coordinates': {'type': 'Point', 'coordinates': [-118.53652, 34.16924]},
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'When its 199degrees 🔅in the Valley, you do the best tasty treats on Ventura Blvd. at Wanderlust Creamery\n\n#icecreamlife\n#wanderlustcreamery \n#Samsonlife \n#KekoaLife \n#teenaclife @… https://t.co/dsYSEmwrHi',
#    'display_text_range': [0, 204],
#    'entities': {'hashtags': [{'text': 'icecreamlife', 'indices': [106, 119]},
#      {'text': 'wanderlustcreamery', 'indices': [120, 139]},
#      {'text': 'Samsonlife', 'indices': [141, 152]},
#      {'text': 'KekoaLife', 'indices': [154, 164]},
#      {'text': 'teenaclife', 'indices': [166, 177]}],
#     'urls': [{'url': 'https://t.co/dsYSEmwrHi',
#       'expanded_url': 'https://www.instagram.com/p/BlcB_BPFio1/?utm_source=ig_twitter_share&igshid=wxp5wi9tdkzr',
#       'display_url': 'instagram.com/p/BlcB_BPFio1/…',
#       'indices': [181, 204]}],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/72R8WlOZWm',
#      'expanded_url': 'https://twitter.com/i/web/status/1020144758973485056',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [106, 129]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056438569'},
#  {'created_at': 'Fri Jul 20 03:14:00 +0000 2018',
#   'id': 1020144767135506432,
#   'id_str': '1020144767135506432',
#   'text': 'Soooooo if these @DanaiGurira Star Trek rumors are true Immma have to become a Trekkie 🖖🏾',
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 347851825,
#    'id_str': '347851825',
#    'name': '🇨🇮 🏴\U000e0067\U000e0062\U000e0077\U000e006c\U000e0073\U000e007f 🇺🇸',
#    'screen_name': 'MmkTyler',
#    'location': 'California, USA',
#    'url': None,
#    'description': 'Mental Health Therapist. Champion for emotional intelligence and I don’t watch any TV that doesn’t make me shout- “FUCKERY!!” 👻 📷 :TylerWllms',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 338,
#    'friends_count': 227,
#    'listed_count': 6,
#    'favourites_count': 10761,
#    'statuses_count': 15154,
#    'created_at': 'Wed Aug 03 13:30:10 +0000 2011',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'FD2300',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme15/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '91D2FA',
#    'profile_sidebar_border_color': 'F5F5F5',
#    'profile_sidebar_fill_color': 'FD2300',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1016567459929718784/R5mSW-fO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1016567459929718784/R5mSW-fO_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/347851825/1411842217',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'DanaiGurira',
#      'name': 'Danai Gurira',
#      'id': 2458256605,
#      'id_str': '2458256605',
#      'indices': [17, 29]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056440515'},
#  {'created_at': 'Fri Jul 20 03:14:01 +0000 2018',
#   'id': 1020144772042780672,
#   'id_str': '1020144772042780672',
#   'text': '@galacticla She loves all of God’s creatures... provided they don’t take good from her',
#   'display_text_range': [12, 86],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020121062179143680,
#   'in_reply_to_status_id_str': '1020121062179143680',
#   'in_reply_to_user_id': 219375098,
#   'in_reply_to_user_id_str': '219375098',
#   'in_reply_to_screen_name': 'galacticla',
#   'user': {'id': 1091131705,
#    'id_str': '1091131705',
#    'name': 'Bardsblond',
#    'screen_name': 'bardsblond',
#    'location': 'SoCal',
#    'url': None,
#    'description': 'Contributor to @ThisIsASN Cohost for @GalaxyPodcast. Support #LAGalaxy #BVB #USMNT #USWNT Former federal prosecutor. The biggest booknerd. I worship my pug.',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1138,
#    'friends_count': 511,
#    'listed_count': 69,
#    'favourites_count': 73919,
#    'statuses_count': 31103,
#    'created_at': 'Tue Jan 15 05:31:49 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '0099B9',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme4/bg.gif',
#    'profile_background_tile': False,
#    'profile_link_color': '0099B9',
#    'profile_sidebar_border_color': '5ED4DC',
#    'profile_sidebar_fill_color': '95E8EC',
#    'profile_text_color': '3C3940',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/811750107838169090/xyUpcSDX_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/811750107838169090/xyUpcSDX_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1091131705/1502599306',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'galacticla',
#      'name': 'Christian',
#      'id': 219375098,
#      'id_str': '219375098',
#      'indices': [0, 11]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056441685'},
#  {'created_at': 'Fri Jul 20 03:14:03 +0000 2018',
#   'id': 1020144781157191680,
#   'id_str': '1020144781157191680',
#   'text': 'Extended sale just for you! 25% OFF &amp; free shipping on all items for US, UK, and Canada orders. Use code: summersal… https://t.co/i65opSJJej',
#   'source': '<a href="http://instagram.com" rel="nofollow">Instagram</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 992091761823567873,
#    'id_str': '992091761823567873',
#    'name': 'VIDA BALI',
#    'screen_name': 'vidabalishop',
#    'location': 'Los Angeles, CA',
#    'url': 'http://www.vidabali.com',
#    'description': 'A brand with a purpose. Supporting artisans worldwide with a commitment to save our oceans 🌊🌴☀️🌎♻️',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 13,
#    'friends_count': 21,
#    'listed_count': 0,
#    'favourites_count': 2,
#    'statuses_count': 63,
#    'created_at': 'Thu May 03 17:21:23 +0000 2018',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/997180413901651968/YMx1yy5k_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/997180413901651968/YMx1yy5k_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/992091761823567873/1527922851',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': {'type': 'Point', 'coordinates': [34.0522, -118.243]},
#   'coordinates': {'type': 'Point', 'coordinates': [-118.243, 34.0522]},
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': 'Extended sale just for you! 25% OFF &amp; free shipping on all items for US, UK, and Canada orders. Use code: summersale. Offers valid until 7/21 😱 @ Los Angeles, California https://t.co/zJeLaUV6W6',
#    'display_text_range': [0, 197],
#    'entities': {'hashtags': [],
#     'urls': [{'url': 'https://t.co/zJeLaUV6W6',
#       'expanded_url': 'https://www.instagram.com/p/BlcB-u9jTRF/?utm_source=ig_twitter_share&igshid=1sih6q0cjitfr',
#       'display_url': 'instagram.com/p/BlcB-u9jTRF/…',
#       'indices': [174, 197]}],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/i65opSJJej',
#      'expanded_url': 'https://twitter.com/i/web/status/1020144781157191680',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [121, 144]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056443858'},
#  {'created_at': 'Fri Jul 20 03:14:04 +0000 2018',
#   'id': 1020144782432075776,
#   'id_str': '1020144782432075776',
#   'text': '@eleanorgrace Yeah same I actually auto corrected it so it didn’t capitalize it',
#   'display_text_range': [14, 79],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020144649875480576,
#   'in_reply_to_status_id_str': '1020144649875480576',
#   'in_reply_to_user_id': 33584077,
#   'in_reply_to_user_id_str': '33584077',
#   'in_reply_to_screen_name': 'eleanorgrace',
#   'user': {'id': 1947451782,
#    'id_str': '1947451782',
#    'name': 'HUES',
#    'screen_name': 'brittvibesonly',
#    'location': 'Los Angeles, CA',
#    'url': 'http://www.commongroundrecords.com',
#    'description': '@commongroundca 🍃🎶',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 588,
#    'friends_count': 323,
#    'listed_count': 11,
#    'favourites_count': 6642,
#    'statuses_count': 4754,
#    'created_at': 'Tue Oct 08 17:20:29 +0000 2013',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '212351',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_link_color': '683870',
#    'profile_sidebar_border_color': 'A6BBB5',
#    'profile_sidebar_fill_color': 'B0A1B6',
#    'profile_text_color': 'B273BB',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/968595416634736641/kUmXYeRd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968595416634736641/kUmXYeRd_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1947451782/1519766095',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'eleanorgrace',
#      'name': 'Eleanor Grace',
#      'id': 33584077,
#      'id_str': '33584077',
#      'indices': [0, 13]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056444162'},
#  {'created_at': 'Fri Jul 20 03:14:05 +0000 2018',
#   'id': 1020144789793079296,
#   'id_str': '1020144789793079296',
#   'text': "I'm not the type of person to hide tips on jobs, life, or money or anything in general. If I have no issue with you… https://t.co/aprEOwMoQV",
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'truncated': True,
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 50489023,
#    'id_str': '50489023',
#    'name': 'Jonathan Ochoa',
#    'screen_name': 'jonathanochoa94',
#    'location': 'Los Angeles, CA',
#    'url': 'http://www.instagram.com/jonathanochoa94',
#    'description': '24',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 1419,
#    'friends_count': 1561,
#    'listed_count': 17,
#    'favourites_count': 11742,
#    'statuses_count': 48817,
#    'created_at': 'Thu Jun 25 00:06:15 +0000 2009',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '642D8B',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme10/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': 'FF0000',
#    'profile_sidebar_border_color': '65B0DA',
#    'profile_sidebar_fill_color': '7AC3EE',
#    'profile_text_color': '3D1957',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1017295036814278656/SMrN12n4_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1017295036814278656/SMrN12n4_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/50489023/1527556347',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': "I'm not the type of person to hide tips on jobs, life, or money or anything in general. If I have no issue with you, I'll gladly help someone out. It's annoying when you see people doing everything, but them not sharing how they got there.",
#    'display_text_range': [0, 239],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/aprEOwMoQV',
#      'expanded_url': 'https://twitter.com/i/web/status/1020144789793079296',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}],
#    'user_mentions': [],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056445917'},
#  {'created_at': 'Fri Jul 20 03:14:06 +0000 2018',
#   'id': 1020144791114268675,
#   'id_str': '1020144791114268675',
#   'text': '@TheView I just caught this mornings The View, running late. I just wanna send @WhoopiGoldberg some love! Thank you… https://t.co/EEr9XhOQjj',
#   'display_text_range': [9, 140],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': True,
#   'in_reply_to_status_id': 1020066771720552450,
#   'in_reply_to_status_id_str': '1020066771720552450',
#   'in_reply_to_user_id': 21258337,
#   'in_reply_to_user_id_str': '21258337',
#   'in_reply_to_screen_name': 'TheView',
#   'user': {'id': 917122143648747520,
#    'id_str': '917122143648747520',
#    'name': 'Irene',
#    'screen_name': 'IreneLovesPR',
#    'location': 'Van Nuys, Los Angeles',
#    'url': None,
#    'description': 'I care!',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 2587,
#    'friends_count': 3235,
#    'listed_count': 4,
#    'favourites_count': 31219,
#    'statuses_count': 24080,
#    'created_at': 'Sun Oct 08 20:18:53 +0000 2017',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': '',
#    'profile_background_image_url_https': '',
#    'profile_background_tile': False,
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1014221851071934464/Yb2m5WJV_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1014221851071934464/Yb2m5WJV_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/917122143648747520/1523492759',
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': '3b77caf94bfc81fe',
#    'url': 'https://api.twitter.com/1.1/geo/id/3b77caf94bfc81fe.json',
#    'place_type': 'city',
#    'name': 'Los Angeles',
#    'full_name': 'Los Angeles, CA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-118.668404, 33.704538],
#       [-118.668404, 34.337041],
#       [-118.155409, 34.337041],
#       [-118.155409, 33.704538]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'extended_tweet': {'full_text': '@TheView I just caught this mornings The View, running late. I just wanna send @WhoopiGoldberg some love! Thank you for telling it like it is! You represented! 💙✊🏽 The judge truly disgusts me.',
#    'display_text_range': [9, 192],
#    'entities': {'hashtags': [],
#     'urls': [],
#     'user_mentions': [{'screen_name': 'TheView',
#       'name': 'The View',
#       'id': 21258337,
#       'id_str': '21258337',
#       'indices': [0, 8]},
#      {'screen_name': 'WhoopiGoldberg',
#       'name': 'Whoopi Goldberg',
#       'id': 284602545,
#       'id_str': '284602545',
#       'indices': [79, 94]}],
#     'symbols': []}},
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [{'url': 'https://t.co/EEr9XhOQjj',
#      'expanded_url': 'https://twitter.com/i/web/status/1020144791114268675',
#      'display_url': 'twitter.com/i/web/status/1…',
#      'indices': [117, 140]}],
#    'user_mentions': [{'screen_name': 'TheView',
#      'name': 'The View',
#      'id': 21258337,
#      'id_str': '21258337',
#      'indices': [0, 8]},
#     {'screen_name': 'WhoopiGoldberg',
#      'name': 'Whoopi Goldberg',
#      'id': 284602545,
#      'id_str': '284602545',
#      'indices': [79, 94]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056446232'},
#  {'created_at': 'Fri Jul 20 03:14:07 +0000 2018',
#   'id': 1020144797225431041,
#   'id_str': '1020144797225431041',
#   'text': '@RightWingRod Awww you’re the sweetest, thanks darling :)',
#   'display_text_range': [14, 57],
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'truncated': False,
#   'in_reply_to_status_id': 1020141991005499392,
#   'in_reply_to_status_id_str': '1020141991005499392',
#   'in_reply_to_user_id': 2288995627,
#   'in_reply_to_user_id_str': '2288995627',
#   'in_reply_to_screen_name': 'RightWingRod',
#   'user': {'id': 360725530,
#    'id_str': '360725530',
#    'name': 'Erica Kaiser',
#    'screen_name': 'EricaMKaiser',
#    'location': 'At A Stadium/Airport Near You',
#    'url': None,
#    'description': 'Owner/Public Relations @kaiserPRmedia | Proud #LSU Alum | Lover of sports, yes, even your team | Opinions are real and they’re spectacular',
#    'translator_type': 'none',
#    'protected': False,
#    'verified': False,
#    'followers_count': 11462,
#    'friends_count': 702,
#    'listed_count': 54,
#    'favourites_count': 28994,
#    'statuses_count': 22132,
#    'created_at': 'Tue Aug 23 17:27:09 +0000 2011',
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme14/bg.gif',
#    'profile_background_tile': True,
#    'profile_link_color': '081417',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'EFEFEF',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1007698201128759296/xKiBVxLh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1007698201128759296/xKiBVxLh_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/360725530/1504291225',
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': None,
#    'follow_request_sent': None,
#    'notifications': None},
#   'geo': None,
#   'coordinates': None,
#   'place': {'id': 'fbd6d2f5a4e4a15e',
#    'url': 'https://api.twitter.com/1.1/geo/id/fbd6d2f5a4e4a15e.json',
#    'place_type': 'admin',
#    'name': 'California',
#    'full_name': 'California, USA',
#    'country_code': 'US',
#    'country': 'United States',
#    'bounding_box': {'type': 'Polygon',
#     'coordinates': [[[-124.482003, 32.528832],
#       [-124.482003, 42.009519],
#       [-114.131212, 42.009519],
#       [-114.131212, 32.528832]]]},
#    'attributes': {}},
#   'contributors': None,
#   'is_quote_status': False,
#   'quote_count': 0,
#   'reply_count': 0,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'entities': {'hashtags': [],
#    'urls': [],
#    'user_mentions': [{'screen_name': 'RightWingRod',
#      'name': 'RightWingRod',
#      'id': 2288995627,
#      'id_str': '2288995627',
#      'indices': [0, 13]}],
#    'symbols': []},
#   'favorited': False,
#   'retweeted': False,
#   'filter_level': 'low',
#   'lang': 'en',
#   'timestamp_ms': '1532056447689'}]

# %% [markdown]
# Display `tweets` in a DataFrame.

# %%
import pandas as pd

# %%
tweets = pd.DataFrame(tweets)

# %%
print(tweets)
# Out:
#   contributors                                        coordinates  \
# 0         None                                               None
# 1         None                                               None
# 2         None  {'type': 'Point', 'coordinates': [-118.53652, ...
# 3         None                                               None
# 4         None                                               None
# 5         None  {'type': 'Point', 'coordinates': [-118.243, 34...
# 6         None                                               None
# 7         None                                               None
# 8         None                                               None
# 9         None                                               None
#
#                        created_at display_text_range  \
# 0  Fri Jul 20 03:13:56 +0000 2018                NaN
# 1  Fri Jul 20 03:13:57 +0000 2018                NaN
# 2  Fri Jul 20 03:13:58 +0000 2018                NaN
# 3  Fri Jul 20 03:14:00 +0000 2018                NaN
# 4  Fri Jul 20 03:14:01 +0000 2018           [12, 86]
# 5  Fri Jul 20 03:14:03 +0000 2018                NaN
# 6  Fri Jul 20 03:14:04 +0000 2018           [14, 79]
# 7  Fri Jul 20 03:14:05 +0000 2018                NaN
# 8  Fri Jul 20 03:14:06 +0000 2018           [9, 140]
# 9  Fri Jul 20 03:14:07 +0000 2018           [14, 57]
#
#                                             entities  \
# 0  {'hashtags': [{'text': 'getnicoletobigbrotherl...
# 1  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 2  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 3  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 4  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 5  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 6  {'hashtags': [], 'urls': [], 'user_mentions': ...
# 7  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 8  {'hashtags': [], 'urls': [{'url': 'https://t.c...
# 9  {'hashtags': [], 'urls': [], 'user_mentions': ...
#
#                                       extended_tweet  favorite_count  \
# 0                                                NaN               0
# 1                                                NaN               0
# 2  {'full_text': 'When its 199degrees 🔅in the Val...               0
# 3                                                NaN               0
# 4                                                NaN               0
# 5  {'full_text': 'Extended sale just for you! 25%...               0
# 6                                                NaN               0
# 7  {'full_text': 'I'm not the type of person to h...               0
# 8  {'full_text': '@TheView I just caught this mor...               0
# 9                                                NaN               0
#
#    favorited filter_level                                                geo  \
# 0      False          low                                               None
# 1      False          low                                               None
# 2      False          low  {'type': 'Point', 'coordinates': [34.16924, -1...
# 3      False          low                                               None
# 4      False          low                                               None
# 5      False          low  {'type': 'Point', 'coordinates': [34.0522, -11...
# 6      False          low                                               None
# 7      False          low                                               None
# 8      False          low                                               None
# 9      False          low                                               None
#
#                          ...                          quoted_status_id_str  \
# 0                        ...                                           NaN
# 1                        ...                           1020119903142072320
# 2                        ...                                           NaN
# 3                        ...                                           NaN
# 4                        ...                                           NaN
# 5                        ...                                           NaN
# 6                        ...                                           NaN
# 7                        ...                                           NaN
# 8                        ...                                           NaN
# 9                        ...                                           NaN
#
#                              quoted_status_permalink reply_count  \
# 0                                                NaN           0
# 1  {'url': 'https://t.co/GWLvP4sqgI', 'expanded':...           0
# 2                                                NaN           0
# 3                                                NaN           0
# 4                                                NaN           0
# 5                                                NaN           0
# 6                                                NaN           0
# 7                                                NaN           0
# 8                                                NaN           0
# 9                                                NaN           0
#
#    retweet_count retweeted                                             source  \
# 0              0     False  <a href="http://twitter.com/download/iphone" r...
# 1              0     False  <a href="http://twitter.com/download/iphone" r...
# 2              0     False  <a href="http://instagram.com" rel="nofollow">...
# 3              0     False  <a href="http://twitter.com/download/iphone" r...
# 4              0     False  <a href="http://twitter.com/download/iphone" r...
# 5              0     False  <a href="http://instagram.com" rel="nofollow">...
# 6              0     False  <a href="http://twitter.com/download/iphone" r...
# 7              0     False  <a href="http://twitter.com" rel="nofollow">Tw...
# 8              0     False  <a href="http://twitter.com/download/iphone" r...
# 9              0     False  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text   timestamp_ms truncated  \
# 0  i need to be tweeting julie’s outfits like #ge...  1532056436524     False
# 1                                          Precisely  1532056437762     False
# 2  When its 199degrees 🔅in the Valley, you do the...  1532056438569      True
# 3  Soooooo if these @DanaiGurira Star Trek rumors...  1532056440515     False
# 4  @galacticla She loves all of God’s creatures.....  1532056441685     False
# 5  Extended sale just for you! 25% OFF &amp; free...  1532056443858      True
# 6  @eleanorgrace Yeah same I actually auto correc...  1532056444162     False
# 7  I'm not the type of person to hide tips on job...  1532056445917      True
# 8  @TheView I just caught this mornings The View,...  1532056446232      True
# 9  @RightWingRod Awww you’re the sweetest, thanks...  1532056447689     False
#
#                                                 user
# 0  {'id': 112626095, 'id_str': '112626095', 'name...
# 1  {'id': 19262339, 'id_str': '19262339', 'name':...
# 2  {'id': 262341207, 'id_str': '262341207', 'name...
# 3  {'id': 347851825, 'id_str': '347851825', 'name...
# 4  {'id': 1091131705, 'id_str': '1091131705', 'na...
# 5  {'id': 992091761823567873, 'id_str': '99209176...
# 6  {'id': 1947451782, 'id_str': '1947451782', 'na...
# 7  {'id': 50489023, 'id_str': '50489023', 'name':...
# 8  {'id': 917122143648747520, 'id_str': '91712214...
# 9  {'id': 360725530, 'id_str': '360725530', 'name...
#
# [10 rows x 34 columns]

# %% [markdown]
# Display just the text of the tweets using DataFrame.

# %%
tweets['text']
# Out:
# 0    i need to be tweeting julie’s outfits like #ge...
# 1                                            Precisely
# 2    When its 199degrees 🔅in the Valley, you do the...
# 3    Soooooo if these @DanaiGurira Star Trek rumors...
# 4    @galacticla She loves all of God’s creatures.....
# 5    Extended sale just for you! 25% OFF &amp; free...
# 6    @eleanorgrace Yeah same I actually auto correc...
# 7    I'm not the type of person to hide tips on job...
# 8    @TheView I just caught this mornings The View,...
# 9    @RightWingRod Awww you’re the sweetest, thanks...
# Name: text, dtype: object

# %% [markdown]
# What is the type of `tweets`?

# %%
type(tweets)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# Write a list comprehension to display the type of each of the objects in `tweets`.

# %%
[type(tweets) for tweets in tweets]
# Out:
# [str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str,
#  str]

# %% [markdown]
# Import the `json` library.

# %% [markdown]
# Create an object called `tweets_string` using `json.dumps()`.
#
# Display the first 500 characters of this string.

# %% [markdown]
# ## Write Tweets to Disk
#
# Using this pattern
#
#     with open(filename_as_string, 'w') as outfile:
#         json.dump(python_object, outfile)
#
# write `tweets` to disk as json.

# %% [markdown]
# ## Read Tweets from Disk
#
# Using this pattern
#
#     with open(filename_as_string) as infile:
#         json_data=infile.read()
#         python_object_from_disk = json.loads(json_data)
#
# read the tweets from the json. Store them as `tweets_from_disk`.

# %% [markdown]
# Display `tweets_from_disk` as a DataFrame.
